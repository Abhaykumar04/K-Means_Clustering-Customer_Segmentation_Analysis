# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import silhouette_score

# %%
data = pd.read_csv(r"D:\Dataset\Mall_Customers.csv")

# %%
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
data.tail()
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
data.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
data = pd.get_dummies(data, columns=['Gender'], prefix=['Gender'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Age                     200 non-null    int64
#  2   Annual Income (k$)      200 non-null    int64
#  3   Spending Score (1-100)  200 non-null    int64
#  4   Gender_Female           200 non-null    bool
#  5   Gender_Male             200 non-null    bool
# dtypes: bool(2), int64(4)
# memory usage: 6.8 KB

# %%
data.describe().T
# Out:
#                         count    mean        std   min    25%    50%     75%  \
# CustomerID              200.0  100.50  57.879185   1.0  50.75  100.5  150.25
# Age                     200.0   38.85  13.969007  18.0  28.75   36.0   49.00
# Annual Income (k$)      200.0   60.56  26.264721  15.0  41.50   61.5   78.00
# Spending Score (1-100)  200.0   50.20  25.823522   1.0  34.75   50.0   73.00
#
#                           max
# CustomerID              200.0
# Age                      70.0
# Annual Income (k$)      137.0
# Spending Score (1-100)   99.0

# %%
# Perform Exploratory Data Analysis (EDA)
# Visualize the relationship between features and spending score
# Histplot:

for i in data.columns:
    f= plt.figure(figsize=(10,10))
    ax = sns.histplot(x=data[i],data=data,bins=40)
    plt.xticks(rotation=90)

# %%
# Pairplot for numerical variables
sns.pairplot(data[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']])
plt.show()

# %%
# Correlation matrix heatmap
correlation_matrix = data[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
# Standardize the data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']])

# %%
# Segmentation using Age and Spending Score

'''Age and spending Score'''

X1 = data[['Age' , 'Spending Score (1-100)']].iloc[: , :].values

inertia = []

for n in range(1 , 11):
    algorithm = (KMeans(n_clusters = n ,init='k-means++', n_init = 10 ,max_iter=300,
                        tol=0.0001,  random_state= 111  , algorithm='elkan') )
    algorithm.fit(X1)
    inertia.append(algorithm.inertia_)
# Out:
# C:\Users\abhay\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: RuntimeWarning: algorithm='elkan' doesn't make sense for a single cluster. Using 'lloyd' instead.
#   warnings.warn(
# C:\Users\abhay\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1440: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %% [markdown]
# #### Plotting Elblow curve

# %%
plt.figure(1 , figsize = (15 ,6))
plt.plot(np.arange(1 , 11) , inertia , 'o')
plt.plot(np.arange(1 , 11) , inertia , '-' , alpha = 0.5)
plt.xlabel('Number of Clusters') , plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# ### Re Initializing K-Means algorithm with 4 clusters

# %%
algorithm = (KMeans(n_clusters = 4 ,init='k-means++', n_init = 10 ,max_iter=300,
                        tol=0.0001,  random_state= 111  , algorithm='elkan') )
algorithm.fit(X1)
labels1 = algorithm.labels_
centroids1 = algorithm.cluster_centers_

# %%
h = 0.02
x_min, x_max = X1[:, 0].min() - 1, X1[:, 0].max() + 1
y_min, y_max = X1[:, 1].min() - 1, X1[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = algorithm.predict(np.c_[xx.ravel(), yy.ravel()])

# %%
plt.figure(1 , figsize = (15 , 7) )
plt.clf()
Z = Z.reshape(xx.shape)
plt.imshow(Z , interpolation='nearest',
           extent=(xx.min(), xx.max(), yy.min(), yy.max()),
           cmap = plt.cm.Pastel2, aspect = 'auto', origin='lower')

plt.scatter( x = 'Age' ,y = 'Spending Score (1-100)' , data = data , c = labels1 ,
            s = 200 )
plt.scatter(x = centroids1[: , 0] , y =  centroids1[: , 1] , s = 300 , c = 'red' , alpha = 0.5)
plt.ylabel('Spending Score (1-100)') , plt.xlabel('Age')
plt.show()

# %%
labels1
# Out:
# array([0, 1, 3, 1, 0, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 0, 0, 3, 1, 0, 1,
#        3, 1, 3, 1, 3, 0, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 2, 1, 2, 0,
#        3, 0, 2, 0, 0, 0, 2, 0, 0, 2, 2, 2, 2, 2, 0, 2, 2, 0, 2, 2, 2, 0,
#        2, 2, 0, 0, 2, 2, 2, 2, 2, 0, 2, 0, 0, 2, 2, 0, 2, 2, 0, 2, 2, 0,
#        0, 2, 2, 0, 2, 0, 0, 0, 2, 0, 2, 0, 0, 2, 2, 0, 2, 0, 2, 2, 2, 2,
#        2, 0, 0, 0, 0, 0, 2, 2, 2, 2, 0, 0, 0, 1, 0, 1, 2, 1, 3, 1, 3, 1,
#        0, 1, 3, 1, 3, 1, 3, 1, 3, 1, 0, 1, 3, 1, 2, 1, 3, 1, 3, 1, 3, 1,
#        3, 1, 3, 1, 3, 1, 2, 1, 3, 1, 3, 1, 3, 1, 3, 0, 3, 1, 3, 1, 3, 1,
#        3, 1, 3, 1, 3, 1, 3, 1, 0, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1,
#        3, 1])

# %%
# Add the cluster labels to your DataFrame
data['Cluster'] = labels1

# Iterate over each cluster and print the segmented data
for cluster_id in data['Cluster'].unique():
    cluster_data = data[data['Cluster'] == cluster_id]
    print(f"\nData for Cluster {cluster_id}:\n")
    print(cluster_data)
# Out:
# Data for Cluster 0:
#
#      CustomerID  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1   19                  15                      39
# 4             5   31                  17                      40
# 16           17   35                  21                      35
# 17           18   20                  21                      66
# 20           21   35                  24                      35
# 27           28   35                  28                      61
# 43           44   31                  39                      61
# 45           46   24                  39                      65
# 47           48   27                  40                      47
# 48           49   29                  40                      42
# 49           50   31                  40                      42
# 51           52   33                  42                      60
# 52           53   31                  43                      54
# 58           59   27                  46                      51
# 61           62   19                  46                      55
# 65           66   18                  48                      59
# 68           69   19                  48                      59
# 69           70   32                  48                      47
# 75           76   26                  54                      54
# 77           78   40                  54                      48
# 78           79   23                  54                      52
# 81           82   38                  54                      55
# 84           85   21                  54                      57
# 87           88   22                  57                      55
# 88           89   34                  58                      60
# 91           92   18                  59                      41
# 93           94   40                  60                      40
# 94           95   32                  60                      42
# 95           96   24                  60                      52
# 97           98   27                  60                      50
# 99          100   20                  61                      49
# 100         101   23                  62                      41
# 103         104   26                  62                      55
# 105         106   21                  62                      42
# 111         112   19                  63                      54
# 112         113   38                  64                      42
# 113         114   19                  64                      46
# 114         115   18                  65                      48
# 115         116   19                  65                      50
# 120         121   27                  67                      56
# 121         122   38                  67                      40
# 122         123   40                  69                      58
# 124         125   23                  70                      29
# 132         133   25                  72                      34
# 142         143   28                  76                      40
# 169         170   32                  87                      63
# 184         185   41                  99                      39
#
#      Gender_Female  Gender_Male  Cluster
# 0            False         True        0
# 4             True        False        0
# 16            True        False        0
# 17           False         True        0
# 20           False         True        0
# 27           False         True        0
# 43            True        False        0
# 45            True        False        0
# 47            True        False        0
# 48            True        False        0
# 49            True        False        0
# 51           False         True        0
# 52            True        False        0
# 58            True        False        0
# 61           False         True        0
# 65           False         True        0
# 68           False         True        0
# 69            True        False        0
# 75           False         True        0
# 77           False         True        0
# 78            True        False        0
# 81           False         True        0
# 84            True        False        0
# 87            True        False        0
# 88            True        False        0
# 91           False         True        0
# 93            True        False        0
# 94            True        False        0
# 95           False         True        0
# 97            True        False        0
# 99           False         True        0
# 100           True        False        0
# 103          False         True        0
# 105           True        False        0
# 111           True        False        0
# 112           True        False        0
# 113          False         True        0
# 114           True        False        0
# 115           True        False        0
# 120          False         True        0
# 121           True        False        0
# 122           True        False        0
# 124           True        False        0
# 132           True        False        0
# 142           True        False        0
# 169          False         True        0
# 184           True        False        0
#
# Data for Cluster 1:
#
#      CustomerID  Age  Annual Income (k$)  Spending Score (1-100)  \
# 1             2   21                  15                      81
# 3             4   23                  16                      77
# 5             6   22                  17                      76
# 7             8   23                  18                      94
# 9            10   30                  19                      72
# 11           12   35                  19                      99
# 13           14   24                  20                      77
# 15           16   22                  20                      79
# 19           20   35                  23                      98
# 21           22   25                  24                      73
# 23           24   31                  25                      73
# 25           26   29                  28                      82
# 29           30   23                  29                      87
# 31           32   21                  30                      73
# 33           34   18                  33                      92
# 35           36   21                  33                      81
# 37           38   30                  34                      73
# 39           40   20                  37                      75
# 41           42   24                  38                      92
# 123         124   39                  69                      91
# 125         126   31                  70                      77
# 127         128   40                  71                      95
# 129         130   38                  71                      75
# 131         132   39                  71                      75
# 133         134   31                  72                      71
# 135         136   29                  73                      88
# 137         138   32                  73                      73
# 139         140   35                  74                      72
# 141         142   32                  75                      93
# 143         144   32                  76                      87
# 145         146   28                  77                      97
# 147         148   32                  77                      74
# 149         150   34                  78                      90
# 151         152   39                  78                      88
# 153         154   38                  78                      76
# 155         156   27                  78                      89
# 157         158   30                  78                      78
# 159         160   30                  78                      73
# 161         162   29                  79                      83
# 163         164   31                  81                      93
# 165         166   36                  85                      75
# 167         168   33                  86                      95
# 171         172   28                  87                      75
# 173         174   36                  87                      92
# 175         176   30                  88                      86
# 177         178   27                  88                      69
# 179         180   35                  93                      90
# 181         182   32                  97                      86
# 183         184   29                  98                      88
# 185         186   30                  99                      97
# 187         188   28                 101                      68
# 189         190   36                 103                      85
# 191         192   32                 103                      69
# 193         194   38                 113                      91
# 195         196   35                 120                      79
# 197         198   32                 126                      74
# 199         200   30                 137                      83
#
#      Gender_Female  Gender_Male  Cluster
# 1            False         True        1
# 3             True        False        1
# 5             True        False        1
# 7             True        False        1
# 9             True        False        1
# 11            True        False        1
# 13            True        False        1
# 15           False         True        1
# 19            True        False        1
# 21           False         True        1
# 23           False         True        1
# 25           False         True        1
# 29            True        False        1
# 31            True        False        1
# 33           False         True        1
# 35            True        False        1
# 37            True        False        1
# 39            True        False        1
# 41           False         True        1
# 123          False         True        1
# 125           True        False        1
# 127          False         True        1
# 129          False         True        1
# 131          False         True        1
# 133           True        False        1
# 135           True        False        1
# 137          False         True        1
# 139           True        False        1
# 141          False         True        1
# 143           True        False        1
# 145          False         True        1
# 147           True        False        1
# 149          False         True        1
# 151          False         True        1
# 153           True        False        1
# 155           True        False        1
# 157           True        False        1
# 159           True        False        1
# 161           True        False        1
# 163           True        False        1
# 165           True        False        1
# 167           True        False        1
# 171          False         True        1
# 173          False         True        1
# 175           True        False        1
# 177          False         True        1
# 179          False         True        1
# 181           True        False        1
# 183           True        False        1
# 185          False         True        1
# 187          False         True        1
# 189           True        False        1
# 191           True        False        1
# 193           True        False        1
# 195           True        False        1
# 197          False         True        1
# 199          False         True        1
#
# Data for Cluster 3:
#
#      CustomerID  Age  Annual Income (k$)  Spending Score (1-100)  \
# 2             3   20                  16                       6
# 6             7   35                  18                       6
# 8             9   64                  19                       3
# 10           11   67                  19                      14
# 12           13   58                  20                      15
# 14           15   37                  20                      13
# 18           19   52                  23                      29
# 22           23   46                  25                       5
# 24           25   54                  28                      14
# 26           27   45                  28                      32
# 28           29   40                  29                      31
# 30           31   60                  30                       4
# 32           33   53                  33                       4
# 34           35   49                  33                      14
# 36           37   42                  34                      17
# 38           39   36                  37                      26
# 44           45   49                  39                      28
# 128         129   59                  71                      11
# 130         131   47                  71                       9
# 134         135   20                  73                       5
# 136         137   44                  73                       7
# 138         139   19                  74                      10
# 140         141   57                  75                       5
# 144         145   25                  77                      12
# 148         149   34                  78                      22
# 150         151   43                  78                      17
# 152         153   44                  78                      20
# 154         155   47                  78                      16
# 156         157   37                  78                       1
# 158         159   34                  78                       1
# 162         163   19                  81                       5
# 164         165   50                  85                      26
# 166         167   42                  86                      20
# 168         169   36                  87                      27
# 170         171   40                  87                      13
# 172         173   36                  87                      10
# 174         175   52                  88                      13
# 176         177   58                  88                      15
# 178         179   59                  93                      14
# 180         181   37                  97                      32
# 182         183   46                  98                      15
# 186         187   54                 101                      24
# 188         189   41                 103                      17
# 190         191   34                 103                      23
# 192         193   33                 113                       8
# 194         195   47                 120                      16
# 196         197   45                 126                      28
# 198         199   32                 137                      18
#
#      Gender_Female  Gender_Male  Cluster
# 2             True        False        3
# 6             True        False        3
# 8            False         True        3
# 10           False         True        3
# 12            True        False        3
# 14           False         True        3
# 18           False         True        3
# 22            True        False        3
# 24            True        False        3
# 26            True        False        3
# 28            True        False        3
# 30           False         True        3
# 32           False         True        3
# 34            True        False        3
# 36            True        False        3
# 38            True        False        3
# 44            True        False        3
# 128          False         True        3
# 130          False         True        3
# 134          False         True        3
# 136           True        False        3
# 138          False         True        3
# 140           True        False        3
# 144          False         True        3
# 148           True        False        3
# 150          False         True        3
# 152           True        False        3
# 154           True        False        3
# 156          False         True        3
# 158          False         True        3
# 162          False         True        3
# 164          False         True        3
# 166          False         True        3
# 168           True        False        3
# 170          False         True        3
# 172          False         True        3
# 174           True        False        3
# 176          False         True        3
# 178          False         True        3
# 180           True        False        3
# 182          False         True        3
# 186           True        False        3
# 188           True        False        3
# 190           True        False        3
# 192          False         True        3
# 194           True        False        3
# 196           True        False        3
# 198          False         True        3
#
# Data for Cluster 2:
#
#      CustomerID  Age  Annual Income (k$)  Spending Score (1-100)  \
# 40           41   65                  38                      35
# 42           43   48                  39                      36
# 46           47   50                  40                      55
# 50           51   49                  42                      52
# 53           54   59                  43                      60
# 54           55   50                  43                      45
# 55           56   47                  43                      41
# 56           57   51                  44                      50
# 57           58   69                  44                      46
# 59           60   53                  46                      46
# 60           61   70                  46                      56
# 62           63   67                  47                      52
# 63           64   54                  47                      59
# 64           65   63                  48                      51
# 66           67   43                  48                      50
# 67           68   68                  48                      48
# 70           71   70                  49                      55
# 71           72   47                  49                      42
# 72           73   60                  50                      49
# 73           74   60                  50                      56
# 74           75   59                  54                      47
# 76           77   45                  54                      53
# 79           80   49                  54                      42
# 80           81   57                  54                      51
# 82           83   67                  54                      41
# 83           84   46                  54                      44
# 85           86   48                  54                      46
# 86           87   55                  57                      58
# 89           90   50                  58                      46
# 90           91   68                  59                      55
# 92           93   48                  60                      49
# 96           97   47                  60                      47
# 98           99   48                  61                      42
# 101         102   49                  62                      48
# 102         103   67                  62                      59
# 104         105   49                  62                      56
# 106         107   66                  63                      50
# 107         108   54                  63                      46
# 108         109   68                  63                      43
# 109         110   66                  63                      48
# 110         111   65                  63                      52
# 116         117   63                  65                      43
# 117         118   49                  65                      59
# 118         119   51                  67                      43
# 119         120   50                  67                      57
# 126         127   43                  71                      35
# 146         147   48                  77                      36
# 160         161   56                  79                      35
#
#      Gender_Female  Gender_Male  Cluster
# 40            True        False        2
# 42           False         True        2
# 46            True        False        2
# 50            True        False        2
# 53           False         True        2
# 54            True        False        2
# 55           False         True        2
# 56            True        False        2
# 57           False         True        2
# 59           False         True        2
# 60           False         True        2
# 62            True        False        2
# 63            True        False        2
# 64           False         True        2
# 66            True        False        2
# 67            True        False        2
# 70           False         True        2
# 71            True        False        2
# 72            True        False        2
# 73            True        False        2
# 74           False         True        2
# 76            True        False        2
# 79            True        False        2
# 80           False         True        2
# 82           False         True        2
# 83            True        False        2
# 85           False         True        2
# 86            True        False        2
# 89            True        False        2
# 90            True        False        2
# 92           False         True        2
# 96            True        False        2
# 98           False         True        2
# 101           True        False        2
# 102          False         True        2
# 104          False         True        2
# 106           True        False        2
# 107          False         True        2
# 108          False         True        2
# 109          False         True        2
# 110          False         True        2
# 116           True        False        2
# 117           True        False        2
# 118           True        False        2
# 119           True        False        2
# 126          False         True        2
# 146          False         True        2
# 160           True        False        2

# %%
sns.scatterplot(x=data['Annual Income (k$)'],y=data['Spending Score (1-100)'],hue=data['Cluster'],legend=True)
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>
